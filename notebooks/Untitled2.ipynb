# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/assignment.csv')

# %%
df
# Out:
#                  Taxon     Unnamed: 1      Habitat  Unnamed: 3           Diet  \
# 0          Monotremata            NaN          NaN         NaN            NaN
# 1       Tachyglossidae            NaN          NaN         NaN            NaN
# 2         Tachyglossus      aculeatus  Terrestrial         NaN  Invertebrates
# 3    Ornithorhynchidae            NaN          NaN         NaN            NaN
# 4      Ornithorhynchus       anatinus      Aquatic         NaN  Invertebrates
# ..                 ...            ...          ...         ...            ...
# 349                NaN            NaN          NaN         NaN            NaN
# 350                NaN            NaN          NaN         NaN            NaN
# 351       Elephantulus       edwardii  Terrestrial         NaN  Invertebrates
# 352       Elephantulus      rugescens  Terrestrial         NaN  Invertebrates
# 353        Petrodromus  tetradactylus  Terrestrial         NaN  Invertebrates
#
# ...
